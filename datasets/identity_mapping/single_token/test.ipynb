# %%
import json
import gzip
import os

# %%
file_path = "/home/huang717/DRAGN/IRM/injectable-alignment-model/datasets/identity_mapping/single_token/single_token_full_distribution_dataset.json.gz"
if os.path.getsize(file_path) == 0:
    raise ValueError(f"{file_path} is empty!")
with gzip.open(file_path, 'rt', encoding="UTF-8") as f:
    dataset = json.load(f)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[2], line 5
#       3     raise ValueError(f"{file_path} is empty!")
#       4 with gzip.open(file_path, 'rt', encoding="UTF-8") as f:
# ----> 5     dataset = json.load(f)
#
# File ~/.conda/envs/test/lib/python3.10/json/__init__.py:293, in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     274 def load(fp, *, cls=None, object_hook=None, parse_float=None,
#     275         parse_int=None, parse_constant=None, object_pairs_hook=None, **kw):
#     276     """Deserialize ``fp`` (a ``.read()``-supporting file-like object containing
#     277     a JSON document) to a Python object.
#     278
#    (...)
#     291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
# ...

# %%
# Test decompression
try:
    with gzip.open(file_path, "rt") as f:
        _ = f.read(10000000000)  # Read first 10 characters
        print(f"***{_}***")
    print("File is valid and decompressible.")
except Exception as e:
    print(f"Corrupted file: {e}")
# Out:
# ******
# File is valid and decompressible.

# %%
if os.path.getsize(file_path) == 0:
    raise ValueError(f"{file_path} is empty!")

# %%
print(os.path.getsize(file_path))
# Out:
# 69
